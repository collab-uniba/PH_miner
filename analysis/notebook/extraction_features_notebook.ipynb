# %% [markdown]
# # PRODUCT "HINT" - LINEE GUIDA EMPIRICHE PER UN EFFICACE LANCIO DI UN PRODOTTO

# %% [markdown]
# ### *1. Obiettivo di ricerca*
# L'obiettivo principale di questa ricerca è di capire quali fattori portano al successo del lancio di un prodotto su Product Hunt (PH), dove il successo è definito se un prodotto è presente tra i più famosi del giorno corrente sulla homepage di PH. I prodotti popolari sono votati dai membri della comunità.
# I prodotti sono scoperti da un "hunter" su PH. Gli hunter sono membri della comunità che "scavano" continuamente su Internet per cercare sempre nuovi prodotti. A volte l'hunter è anche uno dei maker del prodotto che vuole lanciare e pubblicizzare un nuovo prodotto.

# %% [markdown]
# ### *2. Fattori di scuccesso di un prodotto*
# Come fattori di successo sono stati considerati i seguenti:
# * **Reputation (Reputazione)**
# * **Presentation quality (Qualità della presentazione)**
# * **Time (Tempo)**
# * **Affect (or Sentiment, Sentimento)**
# * **Linguistic (Linguistica)**
#
# Di seguito verrà spiegato il significato di ogni fattore:
# * **Reputation:** questo fattore riguarda sia gli hunter che i maker
# * **Presentation quality:** questo fattore è molto importante. In PH vengono utilizzate, ad esempio, tagline brevi e accattivanti, gif animate, emoji e video di Youtube. Anche la lunghezza della descrizione del testo potrebbe avere un effetto positivo per il lancio del prodotto.
# * **Time:** questo fattore riguarda il momento in cui il prodotto è stato "cacciato" o lanciato. Il refresh della homepage di PH viene fatto giornalmente alle ore 00:01 (Pacific Ocean Time) e il momento migliore per postare è entro le ore 9:00 in modo che ci sia tempo sufficiente durante l'intera giornata affinchè le persone possano scoprire e discutere riguardo il prodotto lanciato. Anche sui giorni della settimana in cui bisogna postare c'è una raccomandazione, infatti è consigliabile lanciare un prodotto il Lunedì o il Martedì.
# * **Affect:** l'orientamento positivo, negativo o neutro trasmesso dalla descrizione testuale dei commenti dei maker o dalla descrizione dei post potrebbe influenzare oppure no il numero di voti ricevuti.
# * **Linguistic:** questo fattore riguarda il topic modeling (modellazione degli argomenti). Nel machine learning (apprendimento automatico) e nel natural language processing (elaborazione del linguaggio naturale), il topic model è un tipo di modello statistico per scoprire i topic (argomenti) astratti che si presentano in una raccolta di documenti. Il topic modeling è uno strumento di estrazione del testo frequentemente utilizzato per la scoperta di strutture semantiche nascoste nel testo.

# %% [markdown]
# #### *2.1 Misurare i fattori*
# Di seguito verrà spiegato come si è calcolato ogni fattore:
#
# **Reputation.** Si è operato sul fattore reputation in termini di:<br>
# &nbsp;&nbsp;&nbsp;*1. Hunter reputation*, cioè la reputazione di colui che ha scoperto un nuovo prodotto. Abbiamo misurato la reputazione dell'hunter andando a vedere il &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;numero delle applicazioni fatte, il numero di follower, se dispone di un account twitter e se ha un proprio sito web. Per questi ultimi due punti sono state &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;utilizzate due variabili binarie (Yes/No), mentre per i primi due punti è stata applicata la discretizzazione basata su clustering utilizzando l'**algoritmo &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; k-means**. Nello specifico l'algoritmo k-means è stato implementato importando la libreria `sklearn.cluster` che contiene la classe *KMeans*, mentre la &nbsp;&nbsp;&nbsp;&nbsp;&nbsp; discretizzazione è stata implementata importando la libreria `sklearn.preprocessing` che contiene la classe *KBinsDiscretizer*. <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Per decidere il numero ottimale di cluster è stato implementato il metodo Elbow importando la libreria `yellowbrick.cluster` che contiene la classe &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;*KElbowVisualizer*. <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Sono stati identificati tre tipi di cluster per le metriche *hunter_followers* e *hunter_apps_made*. Nello specifico per hunter_followers: `Low` ( [0, 8516] ), &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`Medium` ( (8516, 32385] ) e `High` ( (32385, 55968] ), mentre per hunter_apps_made: `Low` ( [0, 8] ), `Medium` ( (8, 43] ) e `High` ( (43, 99] ).<br><br>
# &nbsp;&nbsp;&nbsp;*2. Maker reputation*, cioè la reputazione di colui che ha lanciato un nuovo prodotto. Per misurare la reputazione del maker si è seguito lo stesso &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;procedimento utilizzato per l'hunter. In questo caso per la metrica *maker_followers* sono stati identificati tre cluster: `Low` ( [0, 20557] ), `Medium` <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;( (20557, 72984] ) e `High` ( (72984, 105068] ).

# %% [markdown]
# <table style="border-collapse: collapse; border-top: 1px solid black; border-bottom: 1px solid black">
#   <tr style="border-bottom: 1px solid black">
#     <th>post_id</th>
#     <th>post_name</th>
#     <th>hunter_id</th>
#     <th>hunter_name</th>
#     <th>hunter_has_twitter</th>
#     <th>hunter_has_website</th>
#     <th>hunter_followers</th>
#     <th>hunter_apps_made</th>
#     <th>maker_id</th>
#     <th>maker_name</th>
#     <th>maker_has_twitter</th>
#     <th>maker_has_website</th>
#     <th>maker_followers</th>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">29143</td>
#     <td style="width:40%;text-align:center">Hotjar v1</td>
#     <td style="width:40%;text-align:center">36143</td>
#     <td style="width:40%;text-align:center">Stewart Rogers</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">Low</td>
#     <td style="width:40%;text-align:center">Medium</td>
#     <td style="width:40%;text-align:center">9151</td>
#     <td style="width:40%;text-align:center">Dr David Darmanin</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td>Low</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">91504</td>
#     <td style="width:40%;text-align:center">F5Bot</td>
#     <td style="width:40%;text-align:center">473726</td>
#     <td style="width:40%;text-align:center">Min Park</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">Low</td>
#     <td style="width:40%;text-align:center">Low</td>
#     <td style="width:40%;text-align:center">815976</td>
#     <td style="width:40%;text-align:center">Lewis Van Winkle</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td>Low</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">112580</td>
#     <td style="width:40%;text-align:center">Hims</td>
#     <td style="width:40%;text-align:center">2</td>
#     <td style="width:40%;text-align:center">Ryan Hoover</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">High</td>
#     <td style="width:40%;text-align:center">High</td>
#     <td style="width:40%;text-align:center">1069083</td>
#     <td style="width:40%;text-align:center">andrewdudum 🚀</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td>Low</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">119579</td>
#     <td style="width:40%;text-align:center">Deep Learning Platform (DLP)</td>
#     <td style="width:40%;text-align:center">1173498</td>
#     <td style="width:40%;text-align:center">Nasser Njikam</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">Low</td>
#     <td style="width:40%;text-align:center">Low</td>
#     <td style="width:40%;text-align:center">1173498</td>
#     <td style="width:40%;text-align:center">Nasser Njikam</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td>Low</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">121620</td>
#     <td style="width:40%;text-align:center">DLive</td>
#     <td style="width:40%;text-align:center">1190714</td>
#     <td style="width:40%;text-align:center">Md Amirul Islam</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Low</td>
#     <td style="width:40%;text-align:center">Low</td>
#     <td style="width:40%;text-align:center">1273356</td>
#     <td style="width:40%;text-align:center">Charles Wayn</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td >Low</td>
#   </tr>
#   <tr>
#     <td colspan="3" style="text-align: center; font-size: large">......................</td>
#     <td colspan="3" style="text-align: center; font-size: large">......................</td>
#     <td colspan="3" style="text-align: center; font-size: large">......................</td>
#     <td colspan="4" style="text-align: center; font-size: large">......................</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">157956</td>
#     <td style="width:40%;text-align:center">hat.sh</td>
#     <td style="width:40%;text-align:center">1895906</td>
#     <td style="width:40%;text-align:center">shdv</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Low</td>
#     <td style="width:40%;text-align:center">Low</td>
#     <td style="width:40%;text-align:center">1895906</td>
#     <td style="width:40%;text-align:center">shdv</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td>Low</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">157965</td>
#     <td style="width:40%;text-align:center">The Documentation Compendium</td>
#     <td style="width:40%;text-align:center">1911403</td>
#     <td style="width:40%;text-align:center">Kyle Lobo</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">Low</td>
#     <td style="width:40%;text-align:center">Low</td>
#     <td style="width:40%;text-align:center">1911403</td>
#     <td style="width:40%;text-align:center">Kyle Lobo</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td>Low</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">158024</td>
#     <td style="width:40%;text-align:center">Unapp</td>
#     <td style="width:40%;text-align:center">42584</td>
#     <td style="width:40%;text-align:center">vasanth</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Low</td>
#     <td style="width:40%;text-align:center">Medium</td>
#     <td style="width:40%;text-align:center">42584</td>
#     <td style="width:40%;text-align:center">vasanth</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td>Low</td>
#   </tr>
# </table>

# %% [markdown]
# **Presentation quality.** Si è misurata la qualità della presentazione di un prodotto utilizzando le seguenti metriche.<br>
# &nbsp;&nbsp;&nbsp;*1. Tagline length (lunghezza della tagline)*, *2. Text description length (lunghezza del testo della descrizione del post)* e *3. Sentence description length &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;(lunghezza delle frasi presenti nella descrizione)*. Queste tre metriche sono state calcolate come numero di caratteri. In particolare, è stata applicata a &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;queste tre metriche la discretizzazione basata su clustering utilizzando l'**algoritmo k-means**. Nello specifico l'algoritmo k-means è stato implementato &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;importando la libreria `sklearn.cluster` che contiene la classe *KMeans*, mentre la discretizzazione è stata implementata importando la libreria &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`sklearn.preprocessing` che contiene la classe *KBinsDiscretizer*. <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Per decidere il numero ottimale di cluster è stato implementato il metodo Elbow importando la libreria `yellowbrick.cluster` che contiene la classe &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;*KElbowVisualizer*. <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Sono stati identificati tre tipi di cluster per le tre metriche: `Short`, `Medium` e `Long`.<br>
# * Per Tagline length: Short ( [1, 33] ), Medium ( (33, 47] ), Long( (47, 60] ).<br>

# %% [markdown]
# * Per Text description length: Short ( [0, 151] ), Medium ( (151, 268] ), Long ( (268, 422] ).

# %% [markdown]
# * Per Sentence description length: Short ( [0, 97] ), Medium ( (97, 186] ), Long ( (186, 349] ). Per calcolare questa feature è stata utilizzata la funzione `sent_tokenize` contenuta nel package `nltk (Natural Language ToolKit)` che ha permesso di scomporre il testo contenuto nella descrizione del post in frasi.

# %% [markdown]
# &nbsp;&nbsp;&nbsp;*4. Bullet points ed Explicit features (Elenchi puntati/caratteristiche esplicite)*, *5. Emoji in tagline*, *6. Emoji in description*, *7. Youtube Video*, *8. Tweetable &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;images*, *9. Gif*, *10. Special Promotions (Promozioni speciali)*, *11. Promo Codes (Codici Promozionali)* e *12. Questions (Domande)*.<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Sono tutte metriche binarie, `Yes/No`, che indicano se:<br>
# * nella description sono presenti o meno bullet points e/o explicit features ( utilizzando un'espressione regolare eseguibile importando il package `regex`)

# %%
import regex

def __extract_bullet_points_explicit_features(text):
    _bullet_points = []
    bullet_character = '\u2022'
    for i in range(0, len(text)):
        if bullet_character in text[i]:
            _bullet_points.append(text[i])
    return _bullet_points

# %% [markdown]
# * in ogni post nella tagline e/o nella description sono presenti o meno delle emoji ( vengono assegnati dei punti bonus per un uso appropriato delle emoji ). Per calcolare questa feature sono stati importati i package `emoji` e `regex` che hanno permesso di controllare se nel testo sono presenti dei caratteri unicode.

# %%
import emoji
import regex

def __extract_emoji(text):
    emoji_list = []
    data = regex.findall(r'\X', str(text))
    for word in data:
        if any(character in emoji.UNICODE_EMOJI for character in word):
            emoji_list.append(word)
    return emoji_list

# %% [markdown]
# * sono presenti o meno video su Youtube

# %%
for p in _posts:
    index_media = 0
    while index_media < len(_media):
        # check if the current post_id is equal to the post_id of the current media
        if p.id == _media[index_media][0]:
            # check if the media type is 'video'
            if _media[index_media][1] == 'video': 
                # append to the list the link of the video
                video = video + [_media[index_media][2]] 
        index_media = index_media + 1
    if video:
        entry = ['Yes']
    else:
        entry = ['No']

# %% [markdown]
# * sono presenti o meno tweetable images, verificando se l'immagine è rettangolare e cioè se ha una dimensione in scala 2:1

# %%
def get_gcd(a, b):
    """ The GCD (greatest common divisor) is the highest number that evenly divides both width and height. """
    return a if b == 0 else get_gcd(b, a % b)


def calculate_aspect_ratio(width, height):
    temp = 0
    if width == height:
        return 1, 1
    if width < height:
        temp = width
        width = height
        height = temp

    divisor = get_gcd(width, height)
    x = int(width / divisor) if not temp else int(height / divisor)
    y = int(height / divisor) if not temp else int(width / divisor)
    return x, y

for p in _posts:
    index_media = 0
    while index_media < len(_media): 
        # check if the current post_id is equal to the post_id of the current media
        if p.id == _media[index_media][0]: 
            # calculate the image size passing its width and height 
            roughly, ratio = calculate_aspect_ratio(_media[index_media][3], _media[index_media][4]) 
            if (roughly == 2) and (ratio == 1):
                # append to the list the image url
                tweetable_images = tweetable_images + [_media[index_media][5]] 
        index_media = index_media + 1
    if tweetable_images:
        entry = ['Yes']
    else:
        entry = ['No']

# %% [markdown]
# * sono presenti o meno Gif, importando i package `requests` e `mimetypes` per controllare il tipo di url di ogni immagine relativa a ogni post. Potrebbe essere utile includere delle Gif in un post in modo che il prodotto possa spiccare e mostrare meglio il suo valore.

# %%
import mimetypes 
import regex

def is_gif(url):
    found = False
    response = requests.get(url)
    content_type = response.headers['content-type']
    extension = mimetypes.guess_extension(content_type)
    if extension.endswith('gif'):
        found = True
    return found

for p in _posts:
    index_media = 0
    while index_media < len(_media):
        if p.id == _media[index_media][0]:  # check if the current post_id is equal to the post_id of the current media  
            found = is_gif(_media[index_media][5])  # check if an image is a gif passing its url
            if found:
                gif = gif + [_media[index_media][5]]  # append to the list the image url
        index_media = index_media + 1
    if gif:
        entry = ['Yes']
    else:
        entry = ['No']

# %% [markdown]
# * nella description sono presenti o meno promozioni speciali, utilizzando un'espressione regolare basandosi sulla parola-chiave `X%off` ed eseguibile importando il package `regex`

# %%
import regex

def get_keyword_based_heuristics(_keyword):
    return regex.compile(_keyword)

def __extract_offers(text):
    _offers = []
    keywords = get_keyword_based_heuristics(r'\d% off|\d% OFF|\d\d% off|\d\d% OFF|\d\d\d% off|\d\d\d% OFF')
    offer = keywords.search(text)
    if offer:
        _offers.append(offer.group())
    return _offers

for p in _posts:
    index_comment = 0
    while index_comment < len(_comments):
        if p.id == _comments[index_comment][3]:  # check if the current post_id is equal to the post_id of the current comment
            offer = __extract_offers(_comments[index_comment][1])  # extract offers passing the comment body
            if offer:
                offers = offers + offer
        index_comment = index_comment + 1
    if offers:
        entry = ['Yes']
    else:
        entry = ['No']

# %% [markdown]
# * nella description sono presenti o meno codici promozionali, utilizzando un'espressione regolare basandosi sulle parole chiavi `promo` e `discount` ed eseguibile importando il package `regex`

# %%
import regex

def __extract_promo_codes(text):
    _promo_codes = regex.findall('promo=[A-Z0-9]+[a-zA-Z0-9_.+-]+|promo code [A-Z0-9]+[a-zA-Z0-9_.+-]+|discount=[A-Z0-9]+[a-zA-Z0-9_.+-]+|discount code [A-Z0-9]+[a-zA-Z0-9_.+-]+', text)
    return _promo_codes

for p in _posts:
    while index_comment < len(_comments):
        if p.id == _comments[index_comment][3]:  # check if the current post_id is equal to the post_id of the current comment
            promo_code = __extract_promo_codes(_comments[index_comment][1])  # extract promo_codes passing the comment body
            if promo_code:
                promo_codes = promo_codes + promo_code
        index_comment = index_comment + 1
    if promo_codes:
        entry = ['Yes']
    else:
        entry = ['No']

# %% [markdown]
# * nella descritpion sono presenti o meno domande, utilizzando un'espressione regolare eseguibile importando il package `regex`

# %%
import regex

def get_keyword_based_heuristics(_keyword):
    return regex.compile(_keyword)

def get_sentence(text):
    sentence = sent_tokenize(text)
    return sentence

def __extract_questions(text):
    _questions = []
    keyword = get_keyword_based_heuristics(
        r'Let [a-zA-Z0-9_.+-]*|What [a-zA-Z0-9_.+-]*|Where [a-zA-Z0-9_.+-]*|Who [a-zA-Z0-9_.+-]*|Why [a-zA-Z0-9_.+-]*')
    sentence = get_sentence(text)
    for j in range(0, len(sentence)):
        q = keyword.search(sentence[j])
        if q:
            _questions.append(sentence[j])
    return _questions

for p in _posts:
    while index_comment < len(_comments):
        if p.id == _comments[index_comment][3]:  # check if the current post_id is equal to the post_id of the current comment
            question = __extract_questions(_comments[index_comment][1])  # extract questions passing the comment body
            if question:
                questions = questions + question
        index_comment = index_comment + 1
    if questions:
        entry = ['Yes']
    else:
        entry = ['No']

# %% [markdown]
# &nbsp;&nbsp;&nbsp;*13. Numero di Gif*<br>
# &nbsp;&nbsp;&nbsp;Per ogni post è stato calcolato il numero di Gif presenti

# %% [markdown]
# &nbsp;&nbsp;&nbsp;*14. Numero di tag*<br>
# &nbsp;&nbsp;&nbsp;É stato calcolato il numero di tag che sono stati scelti dal maker al momento della creazione del post

# %%
for p in _posts:
    tags_number = session.query(func.count(Topic.name)).filter(Topic.post_id == p.id).scalar()
    entry = [tags_number]

# %% [markdown]
# &nbsp;&nbsp;&nbsp;*15. Versione*<br>
# &nbsp;&nbsp;&nbsp;Metrica che indica la versione del prodotto. Operando sul link di ogni post questa metrica è stata calcolata utilizzando un'espressione regolare basata sulla &nbsp;&nbsp;&nbsp;parola-chiave `post/app-versione` ed eseguibile importando il package `regex`

# %%
import regex

def get_keyword_based_heuristics(_keyword):
    return regex.compile(_keyword)


def __extract_version(url):
    url = url + ' '
    version_number = '1.0'
    keyword = get_keyword_based_heuristics(r'-+v+([\d-]+)+\s|-+([\d-]+)+\s')
    _version = keyword.search(url)
    if _version:
        v = _version.group()
        v = v.replace('-', '.')
        if v[1] == 'v':
            if v.count('.') >= 2:
                version_number = v[2:]
            else:
                version_number = v[2:len(v)-1] + '.0'
        else:
            if v.count('.') >= 2:
                version_number = v[1:]
            else:
                version_number = v[1:len(v)-1] + '.0'
    return version_number

for p in _posts:
    version = __extract_version(p.discussion_url)
    entry = [version]

# %% [markdown]
# &nbsp;&nbsp;&nbsp;*16. Nurturing*<br>
# &nbsp;&nbsp;&nbsp;Per ogni post è stato controllato se il maker e l'hunter si sono impegnati nella discussione con gli altri membri della comunità che hanno lasciato dei &nbsp;&nbsp;&nbsp;commenti. I risultati sono stati considerati come delle variabili binarie, `Yes/No`. Un maker o un hunter partecipante e comunicativo può promuovere un &nbsp;&nbsp;&nbsp;giudizio più favorevole per il prodotto che di conseguenza ottiene più voti.

# %%
for p in _posts:
    index_comment = 0
    while index_comment < len(_comments):
        if p.id == _comments[index_comment][3]:  # check if the current post_id is equal to the post_id of the current comment
            if _comments[index_comment][4] == maker_id:  # check if the maker_id that partecipates in the current comment is equal to the current maker_id
                maker_follows_up_on_comments.insert(0, _comments[index_comment][5])
            else:
                hunter_follows_up_on_comments.insert(0, _comments[index_comment][5])
        index_comment = index_comment + 1
    
    if hunter_follows_up_on_comments:
        entry = ['Yes']
    else:
        entry = ['No']
        
    if maker_follows_up_on_comments:
        entry = ['Yes']
    else:
        entry = ['No']

# %% [markdown]
# <table style="border-collapse: collapse; border-top: 1px solid black; border-bottom: 1px solid black">
#   <tr style="border-bottom: 1px solid black">
#     <th>post_id</th>
#     <th>post_name</th>
#     <th>version</th>
#     <th>tags_number</th>
#     <th>is_featured</th>
#     <th>score</th>
#     <th>text_description_length</th>
#     <th>sentence_length_in_the_description</th>
#     <th>bullet_points_explicit_features</th>
#     <th>emoji_in_description</th>
#     <th>tagline_length</th>
#     <th>emoji_in_tagline</th>
#     <th>are_there_video</th>
#     <th>are_there_tweetable_images</th>
#     <th>are_there_gif_images</th>
#     <th>number_of_gif</th>
#     <th>offers</th>
#     <th>promo_discount_codes</th>
#     <th>are_there_questions</th>
#     <th>hunter_id</th>
#     <th>hunter_name</th>
#     <th>hunter_follows_up_on_comments</th>
#     <th>maker_id</th>
#     <th>maker_name</th>
#     <th>maker_follows_up_on_comments</th>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">29143</td>
#     <td style="width:40%;text-align:center">Hotjar v1</td>
#     <td style="width:40%;text-align:center">1.0</td>
#     <td style="width:40%;text-align:center">4</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">2771</td>
#     <td style="width:40%;text-align:center">Short</td>
#     <td style="width:40%;text-align:center">Short</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Long</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">0</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">36143</td>
#     <td style="width:40%;text-align:center">Stewart Rogers</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">9151</td>
#     <td style="width:40%;text-align:center">Dr David Darmanin</td>
#     <td>No</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">91504</td>
#     <td style="width:40%;text-align:center">F5Bot</td>
#     <td style="width:40%;text-align:center">1.0</td>
#     <td style="width:40%;text-align:center">6</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">313</td>
#     <td style="width:40%;text-align:center">Medium</td>
#     <td style="width:40%;text-align:center">Medium</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Long</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">0</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">473726</td>
#     <td style="width:40%;text-align:center">Min Park</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">815976</td>
#     <td style="width:40%;text-align:center">Lewis Van Winkle</td>
#     <td>Yes</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">112580</td>
#     <td style="width:40%;text-align:center">Hims</td>
#     <td style="width:40%;text-align:center">1.0</td>
#     <td style="width:40%;text-align:center">2</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">442</td>
#     <td style="width:40%;text-align:center">Long</td>
#     <td style="width:40%;text-align:center">Short</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Long</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">0</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">2</td>
#     <td style="width:40%;text-align:center">Ryan Hoover</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">1069083</td>
#     <td style="width:40%;text-align:center">andrewdudum 🚀</td>
#     <td>No</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">119579</td>
#     <td style="width:40%;text-align:center">Deep Learning Platform (DLP)</td>
#     <td style="width:40%;text-align:center">1.0</td>
#     <td style="width:40%;text-align:center">3</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">208</td>
#     <td style="width:40%;text-align:center">Long</td>
#     <td style="width:40%;text-align:center">Short</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Long</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">0</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">1173498</td>
#     <td style="width:40%;text-align:center">Nasser Njikam</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">1173498</td>
#     <td style="width:40%;text-align:center">Nasser Njikam</td>
#     <td>No</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">121620</td>
#     <td style="width:40%;text-align:center">DLive</td>
#     <td style="width:40%;text-align:center">1.0</td>
#     <td style="width:40%;text-align:center">4</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">166</td>
#     <td style="width:40%;text-align:center">Medium</td>
#     <td style="width:40%;text-align:center">Short</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Medium</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">1</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">1190714</td>
#     <td style="width:40%;text-align:center">Md Amirul Islam</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">1273356</td>
#     <td style="width:40%;text-align:center">Charles Wayn</td>
#     <td>Yes</td>
#   </tr>
#   <tr>
#     <td colspan="5" style="text-align: center; font-size: large">......................</td>
#     <td colspan="5" style="text-align: center; font-size: large">......................</td>
#     <td colspan="5" style="text-align: center; font-size: large">......................</td>
#     <td colspan="5" style="text-align: center; font-size: large">......................</td>
#     <td colspan="5" style="text-align: center; font-size: large">......................</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">157956</td>
#     <td style="width:40%;text-align:center">hat.sh</td>
#     <td style="width:40%;text-align:center">1.0</td>
#     <td style="width:40%;text-align:center">4</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">209</td>
#     <td style="width:40%;text-align:center">Medium</td>
#     <td style="width:40%;text-align:center">Short</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Long</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">1</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">1895906</td>
#     <td style="width:40%;text-align:center">shdv</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">1895906</td>
#     <td style="width:40%;text-align:center">shdv</td>
#     <td>Yes</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">157965</td>
#     <td style="width:40%;text-align:center">The Documentation Compendium</td>
#     <td style="width:40%;text-align:center">1.0</td>
#     <td style="width:40%;text-align:center">4</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">154</td>
#     <td style="width:40%;text-align:center">Medium</td>
#     <td style="width:40%;text-align:center">Short</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Long</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">2</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">1911403</td>
#     <td style="width:40%;text-align:center">Kyle Lobo</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">1911403</td>
#     <td style="width:40%;text-align:center">Kyle Lobo</td>
#     <td>Yes</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">158024</td>
#     <td style="width:40%;text-align:center">Unapp</td>
#     <td style="width:40%;text-align:center">1.0</td>
#     <td style="width:40%;text-align:center">1</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">438</td>
#     <td style="width:40%;text-align:center">Short</td>
#     <td style="width:40%;text-align:center">Short</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Long</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">0</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">42584</td>
#     <td style="width:40%;text-align:center">vasanth</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">42584</td>
#     <td style="width:40%;text-align:center">vasanth</td>
#     <td>Yes</td>
#   </tr>
# </table>

# %% [markdown]
# **Time.** Si è operato sul fattore time utilizzando le seguenti metriche.<br>
# &nbsp;&nbsp;&nbsp;*1. Product Posted Time ( Tempo di lancio del prodotto, PST )*, cioè è stato controllato se il lancio del post è avvenuto all'orario consigliato.

# %%
def is_best_posted_time(_hour, _minute, _second):
    _found = False
    if (_hour > 0) and (_hour < 9):
        _found = True
    elif _hour == 0:
        if (_minute == 0) and ((_second > 0) and (_second < 59)):
            _found = True
        elif _minute > 0:
            _found = True
        else:
            _found = False
    return _found

for p in _posts:
    best_launch_time = is_best_posted_time(p.created_at.hour, p.created_at.minute, p.created_at.second)
    entry = [best_launch_time]

# %% [markdown]
# &nbsp;&nbsp;&nbsp;*2. Day of week (Giorno della settimana)*, cioè è stato controllato se il post è stato lanciato di Lunedì (Monday) o di Martedì (Tuesday).

# %%
import calendar 

def is_best_launched_day(_hour, _minute, _second, _ld):
    _found = False
    if (_hour >= 0) and (_minute > 1):
        if (_ld == 'Monday') or (_ld == 'Tuesday'):
            _found = True
    else:
        _found = False
    return _found

for p in _posts:
    launch_day = get_day_name_from_date(p.created_at.year, p.created_at.month, p.created_at.day)
    best_launch_day = is_best_launched_day(p.created_at.hour, p.created_at.minute, p.created_at.second, launch_day)
    entry = [best_launch_day]

# %% [markdown]
# &nbsp;&nbsp;&nbsp;*3. Weekend*, cioè è stato controllato se il post è stato lanciato di Sabato (Saturday) o di Domenica (Sunday).

# %%
import calendar

def get_day_name_from_date(year, month, day):
    my_date = datetime.datetime(year, month, day)
    date_day = calendar.day_name[my_date.weekday()]
    return date_day

def is_weekend(followers_count, max_follower, _ld):
    _found = False
    if (followers_count < max_follower) and ((_ld == 'Saturday') or (_ld == 'Sunday')):
        _found = True
    else:
        _found = False
    return _found

for p in _posts:
    launch_day = get_day_name_from_date(p.created_at.year, p.created_at.month, p.created_at.day)
    max_follower = session.query(func.max(User.followers_count)).scalar()
    maker_id = session.query(Apps.maker_id).filter(Apps.post_id == p.id).one()[0]
    maker = session.query(User.id, User.twitter_username, User.website_url, User.followers_count).filter(User.id == maker_id).one()
    weekend = is_weekend(maker.followers_count, max_follower, launch_day)

# %% [markdown]
# <table style="border-collapse: collapse; border-top: 1px solid black; border-bottom: 1px solid black">
#   <tr style="border-bottom: 1px solid black">
#     <th>post_id</th>
#     <th>post_name</th>
#     <th>created_at_day</th>
#     <th>created_at_daytime</th>
#     <th>launched_day</th>
#     <th>is_best_time_to_launch</th>
#     <th>is_best_day_to_launch</th>
#     <th>is_weekend</th>
#     <th>hunter_id</th>
#     <th>hunter_name</th>
#     <th>maker_id</th>
#     <th>maker_name</th>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">29143</td>
#     <td style="width:40%;text-align:center">Hotjar v1</td>
#     <td style="width:40%;text-align:center">2018-08-30</td>
#     <td style="width:40%;text-align:center">2015-07-28 05:12:28</td>
#     <td style="width:40%;text-align:center">Tuesday</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">36143</td>
#     <td style="width:40%;text-align:center">Stewart Rogers</td>
#     <td style="width:40%;text-align:center">9151</td>
#     <td>Dr David Darmanin</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">91504</td>
#     <td style="width:40%;text-align:center">F5Bot</td>
#     <td style="width:40%;text-align:center">2018-10-12</td>
#     <td style="width:40%;text-align:center">2018-10-12 00:00:00</td>
#     <td style="width:40%;text-align:center">Friday</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">473726</td>
#     <td style="width:40%;text-align:center">Min Park</td>
#     <td style="width:40%;text-align:center">815976</td>
#     <td>Lewis Van Winkle</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">112580</td>
#     <td style="width:40%;text-align:center">Hims</td>
#     <td style="width:40%;text-align:center">2018-09-10</td>
#     <td style="width:40%;text-align:center">2017-11-03 03:02:00</td>
#     <td style="width:40%;text-align:center">Friday</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">2</td>
#     <td style="width:40%;text-align:center">Ryan Hoover</td>
#     <td style="width:40%;text-align:center">1069083</td>
#     <td>andrewdudum 🚀</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">119579</td>
#     <td style="width:40%;text-align:center">Deep Learning Platform (DLP)</td>
#     <td style="width:40%;text-align:center">2018-12-08</td>
#     <td style="width:40%;text-align:center">2018-12-08 00:00:00</td>
#     <td style="width:40%;text-align:center">Saturday</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">1173498</td>
#     <td style="width:40%;text-align:center">Nasser Njikam</td>
#     <td style="width:40%;text-align:center">1173498</td>
#     <td>Nasser Njikam</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">121620</td>
#     <td style="width:40%;text-align:center">DLive</td>
#     <td style="width:40%;text-align:center">2018-07-06</td>
#     <td style="width:40%;text-align:center">2018-07-06 00:00:00</td>
#     <td style="width:40%;text-align:center">Friday</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">1190714</td>
#     <td style="width:40%;text-align:center">Md Amirul Islam</td>
#     <td style="width:40%;text-align:center">1273356</td>
#     <td>Charles Wayn</td>
#   </tr>
#   <tr>
#       <td colspan="3" style="text-align: center; font-size: large">......................</td>
#       <td colspan="3" style="text-align: center; font-size: large">......................</td>
#       <td colspan="3" style="text-align: center; font-size: large">......................</td>
#       <td colspan="3" style="text-align: center; font-size: large">......................</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">157956</td>
#     <td style="width:40%;text-align:center">hat.sh</td>
#     <td style="width:40%;text-align:center">2019-06-09</td>
#     <td style="width:40%;text-align:center">2019-06-09 00:00:00</td>
#     <td style="width:40%;text-align:center">Sunday</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">1895906</td>
#     <td style="width:40%;text-align:center">shdv</td>
#     <td style="width:40%;text-align:center">1895906</td>
#     <td>shdv</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">157965</td>
#     <td style="width:40%;text-align:center">The Documentation Compendium</td>
#     <td style="width:40%;text-align:center">2019-06-09</td>
#     <td style="width:40%;text-align:center">2019-06-09 02:19:08</td>
#     <td style="width:40%;text-align:center">Sunday</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">1911403</td>
#     <td style="width:40%;text-align:center">Kyle Lobo</td>
#     <td style="width:40%;text-align:center">1911403</td>
#     <td>Kyle Lobo</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:center">158024</td>
#     <td style="width:40%;text-align:center">Unapp</td>
#     <td style="width:40%;text-align:center">2019-06-10</td>
#     <td style="width:40%;text-align:center">2019-06-10 00:09:10</td>
#     <td style="width:40%;text-align:center">Monday</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">Yes</td>
#     <td style="width:40%;text-align:center">No</td>
#     <td style="width:40%;text-align:center">42584</td>
#     <td style="width:40%;text-align:center">vasanth</td>
#     <td style="width:40%;text-align:center">42584</td>
#     <td>vasanth</td>
#   </tr>
# </table>

# %% [markdown]
# **Affect.** Ci si è basati sull'analisi del sentimento per rilevare la polarità e i tratti di personalità che provengono dai commenti fatti dal maker il giorno in cui ha lanciato il prodotto e dalla descrizione del post scritta dal maker stesso. Per estrarre questa feature sono state utilizzate le due seguenti metriche:<br>
# &nbsp;&nbsp;&nbsp;*1. Positive Sentiment* e *2. Negative Sentiment*<br>
# &nbsp;&nbsp;&nbsp;Per catturare il sentimento di questi commenti è stato usato `SentiStrength`, uno strumento di analisi dei sentimenti già utilizzato in social computing, che &nbsp;&nbsp;&nbsp;è in grado di gestire brevi testi informali tra cui abbreviazioni, intensificatori ed emoticon. Basandosi sul presupposto che una frase può trasmettere un &nbsp;&nbsp;&nbsp;sentimento misto, SentiStrength genera punteggi di sentimento sia positivi che negativi per un testo di input. I punteggi di sentimento positivi vanno da +1 &nbsp;&nbsp;&nbsp;(assenza di sentimento positivo) a +5 (estremamente positivo), mentre i punteggi di sentimento negativi vanno da -1 (assenza di sentimento negativo) a -5 &nbsp;&nbsp;&nbsp;(estremamente negativo). Un commento è neutro quando il punteggio del sentimento positivo è uguale a +1 e il punteggio del sentimeno negativo è uguale &nbsp;&nbsp;&nbsp;a -1.

# %%
from sentistrength import PySentiStr

def setup_sentistrength_path(s):
    s.setSentiStrengthPath(os.getcwd() + '\\affect_resources\\SentiStrengthCom.jar')
    s.setSentiStrengthLanguageFolderPath(os.getcwd() + '\\affect_resources\\SentiStrength_Data\\')

# %%
def __extract_maker_sentiment(sentiment, text):
    maker_sentiment = sentiment.getSentiment(text, score='binary')
    return maker_sentiment

# %%
def discretize_affect_feature(positive_sentiment, negative_sentiment):
    discretized_positive_sentiment_score = False
    discretized_negative_sentiment_score = False
    discretized_neutral_sentiment_score = False
    if (positive_sentiment == +1) and ((negative_sentiment == -2) or (negative_sentiment == -3) or
                                       (negative_sentiment == -4) or (negative_sentiment == -5)):
        discretized_positive_sentiment_score = False
        discretized_negative_sentiment_score = True
        discretized_neutral_sentiment_score = False
    elif ((positive_sentiment == +2) or (positive_sentiment == +3) or (positive_sentiment == +4) or
          (positive_sentiment == +5)) and (negative_sentiment == -1):
        discretized_positive_sentiment_score = True
        discretized_negative_sentiment_score = False
        discretized_neutral_sentiment_score = False
    elif (positive_sentiment == +1) and (negative_sentiment == -1):
        discretized_positive_sentiment_score = False
        discretized_negative_sentiment_score = False
        discretized_neutral_sentiment_score = True
    elif ((positive_sentiment == +2) or (positive_sentiment == +3) or (positive_sentiment == +4) or
          (positive_sentiment == +5)) and ((negative_sentiment == -2) or (negative_sentiment == -3) or
                                           (negative_sentiment == -4) or (negative_sentiment == -5)):
        discretized_positive_sentiment_score = True
        discretized_negative_sentiment_score = True
        discretized_neutral_sentiment_score = False
    return discretized_positive_sentiment_score, discretized_negative_sentiment_score, discretized_neutral_sentiment_score

# %%
entries = list()
for p in _posts:
    comments = []
    index_comment = 0
    while index_comment < len(_comments):
        # check if the current post_id is equal to the post_id of the current comment
        if p.id == _comments[index_comment][3]:
            """ Extraction of maker sentiment based on his post comments written the day of launch """
            if _comments[index_comment][4] == maker_id:
                # date of maker's comment written the day the post was launched
                comment_date = _comments[index_comment][2]
                # cut the comments written days after the post was launched
                if (p.created_at.year == comment_date.year) and (p.created_at.month == comment_date.month) and (
                    p.created_at.day == comment_date.day):
                    if not comments:
                        comments = [_comments[index_comment][1]]
                    else:
                        comments = comments + [_comments[index_comment][1]]
        index_comment = index_comment + 1
    
    # Append to the list the maker comment sentiment
    if comments:
        comment = '\n'.join(comments)
        sentiment = __extract_maker_sentiment(senti, comment)
    else:
        comment = ''
        sentiment = [[1, -1]]
    entry = entry + [comment, sentiment[0][0], sentiment[0][1], '', '', '']
    
    entries.append(entry)

entries = discretize_affect_feature(entries[1], entries[2])

# %% [markdown]
# Qui di seguito alcuni esempi ricavati dall'analisi del sentimento basato sui commenti fatti dal maker il giorno in cui ha lanciato il prodotto
# <table style="border-top: 1px solid black; border-bottom: 1px solid black; float: left">
#     <tr>
#         <th></th>
#         <th></th>
#         <th colspan=7></th>
#         <th style="border-bottom: 1px solid black;text-align: center" colspan=4>Sentiment Strength Scores</th>
#         <th style="border-bottom: 1px solid black;text-align: center" colspan=6>Discretized Sentiment Scores</th>
#     </tr>
#     <tr style="border-bottom: 1px solid black">
#         <th>Post Id</th>
#         <th style="text-align: center">Post Name</th>
#         <th style="text-align: center">Author Name</th>
#         <th style="text-align: center" colspan=6>Makers Posts Comments</th>
#         <th colspan=2 style="text-align:center">Positive</th>
#         <th colspan=2 style="text-align:center">Negative</th>
#         <th colspan=2 style="text-align:center">Positive</th>
#         <th colspan=2 style="text-align:center">Negative</th>
#         <th colspan=2 style="text-align:center">Neutral</th>
#     </tr>
#     <tr style="border-bottom: 1px solid black">
#       <td>121620</td>
#       <td style="text-align: center">DLive</td>
#       <td style="text-align: center">Charles Wayn</td>
#       <td style="width:40%;text-align:left" colspan=6>@davecraige @rrhoover , Thanks for supporting DLive. We often see YouTube or Twitch users being judged on their content by the company itself. At DLive we allow the Community to vote whether content can be scene or not, this can be done through upvoting and flagging on the Steem blockchain. DLive also aims to create a platform where all content creators can feel appreciated and monetize their original content, without any fees involved.</td>
#       <td colspan=2 style="text-align:center">+2</td>
#       <td colspan=2 style="text-align:center">-2</td>
#       <td colspan=2 style="text-align:center">True</td>
#       <td colspan=2 style="text-align:center">True</td>
#       <td colspan=2 style="text-align:center">False</td>
#   </tr>
#   <tr>
#     <td style="border-bottom: 1px solid black" rowspan=4>122220</td>
#     <td style="border-bottom: 1px solid black;text-align: center" rowspan= 4>Sunsama</td>
#     <td style="border-bottom: 1px solid black;text-align: center" rowspan= 4>Travis Meyer</td>
#     <td style="width:40%;text-align:left" colspan=6>@ramon_pans thanks! The free tier plan lets you complete up to 100 tasks total. 100 was the number we found gave folks enough time to try it out and decide whether they actually liked using Sunsama as part of their daily workflow. Once you've completed 100 tasks, you can still use the app on the free plan, but you won't be able to see your past task completions until you upgrade.</td>
#     <td rowspan=4 colspan=2 style="border-bottom: 1px solid black;text-align:center">+3</td>
#     <td rowspan=4 colspan=2 style="border-bottom: 1px solid black;text-align:center">-2</td>
#     <td rowspan=4 colspan=2 style="border-bottom: 1px solid black;text-align:center">True</td>
#     <td rowspan=4 colspan=2 style="border-bottom: 1px solid black;text-align:center">True</td>
#     <td rowspan=4 colspan=2 style="border-bottom: 1px solid black;text-align:center">False</td>
#   </tr>
#   <tr>
#     <td  style="width:40%;text-align:left" colspan=6>@thepriyadarshy @prokotasic hm, are you by chance trying with safari in a private window? shoot us an email at support@sunsama.com and we'll get you sorted out!</td>
#   </tr>
#   <tr>
#     <td  style="width:40%;text-align:left" colspan=6>@ajaffarali thanks for constructive feedback. We heard a lot of requests today for recurring tasks from fellow hunters. It's something that certainly fits in quite naturally to the theme of sunsama as the home for the tasks you want to work on each day. We'll do our best to bring it to life for you.</td>
#   </tr>
#   <tr style="border-bottom: 1px solid black">
#     <td style="width:40%;text-align:left" colspan=6>@p01ds thanks, glad we were able to find each other! Mobile app definitely a big project on our radar. We're holding off a bit until we have the resources to make sure we do it right. In the meanwhile, since we built the web app to be responsive on mobile, a lot of folks just add Sunsama to their home screen in iOS. We'll be making a few tweaks to make that experience even better in the coming days.</td>
#   </tr>
#   <tr>
#     <td style="border-bottom: 1px solid black" rowspan=5>128204</td>
#     <td style="border-bottom: 1px solid black;text-align: center" rowspan=5>Brightland</td>
#     <td style="border-bottom: 1px solid black;text-align: center" rowspan= 5>Aishwarya Iyer</td>
#     <td style="width:40%;text-align:left" colspan=6>@me_mary_22 thank you!</td>
#     <td rowspan=5 colspan=2 style="text-align:center">+3</td>
#     <td rowspan=5 colspan=2 style="text-align:center">-1</td>
#     <td rowspan=5 colspan=2 style="text-align:center">True</td>
#     <td rowspan=5 colspan=2 style="text-align:center">False</td>
#     <td rowspan=5 colspan=2 style="text-align:center">False</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:left" colspan=6>@tabansi thank you! Not yet, hopefully soon!</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:left" colspan=6>@igityan_hayarpy extra virgin olive oil! Brightland is handcrafted in California.</td>
#   </tr>
#   <tr>
#     <td style="width:40%;text-align:left" colspan=6>@moeamaya thank you so much moe! We were inspired by Matisse and colorful, beautiful California produce when developing the color palette ❤️??</td>
#   </tr>
#   <tr style="border-bottom: 1px solid black">
#     <td style="width:40%;text-align:left" colspan=6>@gyllanderjenny thanks Jenny! We have actually received quite a bit of interest from people in a London and Paris - you will be the first to know when we arrive. Have some exciting new products and collaborations in the works. :)</td>
#   </tr>
# </table>

# %%
entries = list()
for p in _posts:
    entry = [p.description]
    if p.description:
        """ Extraction of maker sentiment based on the description of his post """
        sentiment_description = __extract_maker_sentiment(senti, p.description)
        entry = entry + [sentiment_description[0][0], sentiment_description[0][1], '', '', '']
    else:
        entry = entry + [1, -1, '', '', '']
    entries.append(entry)

entries = discretize_affect_feature(entries[1], entries[2])

# %% [markdown]
# Qui di seguito alcuni esempi ricavati dall'analisi del sentimento basato sulla descrizione del post scritta dal maker
# <table style="border-top: 1px solid black; border-bottom: 1px solid black; float: left">
#     <tr>
#         <th></th>
#         <th></th>
#         <th colspan=7></th>
#         <th style="border-bottom: 1px solid black;text-align: center" colspan=4>Sentiment Strength Scores</th>
#         <th style="border-bottom: 1px solid black;text-align: center" colspan=6>Discretized Sentiment Scores</th>
#     </tr>
#     <tr style="border-bottom: 1px solid black">
#         <th>Post Id</th>
#         <th style="text-align: center">Post Name</th>
#         <th style="text-align: center">Maker Name</th>
#         <th style="text-align: center" colspan=6>Makers Posts Descriptions</th>
#         <th colspan=2 style="text-align:center">Positive</th>
#         <th colspan=2 style="text-align:center">Negative</th>
#         <th colspan=2 style="text-align:center">Positive</th>
#         <th colspan=2 style="text-align:center">Negative</th>
#         <th colspan=2 style="text-align:center">Neutral</th>
#     </tr>
#     <tr style="border-bottom: 1px solid black">
#       <td>29143</td>
#       <td style="text-align: center">Hotjar v1</td>
#       <td style="text-align: center">Dr David Darmanin</td>
#       <td style="width:40%;text-align:left" colspan=6>Hotjar v1 is a new and easy way to truly understand your web and mobile site visitors. Find your hottest opportunities for growth today.</td>
#       <td colspan=2 style="text-align:center">+2</td>
#       <td colspan=2 style="text-align:center">-1</td>
#       <td colspan=2 style="text-align:center">True</td>
#       <td colspan=2 style="text-align:center">False</td>
#       <td colspan=2 style="text-align:center">False</td>
#   </tr>
#   <tr style="border-bottom: 1px solid black">
#     <td>91504</td>
#     <td style="text-align: center">F5Bot</td>
#     <td style="text-align: center">Lewis Van Winkle</td>
#     <td style="width:40%;text-align:left" colspan=6>F5Bot is a free service that emails you when your selected keywords are mentioned on Reddit, Hacker News, or Lobsters. Use it to monitor your brand, your projects, or just topics that you're interested in.</td>
#     <td colspan=2 style="text-align:center">+2</td>
#     <td colspan=2 style="text-align:center">-1</td>
#     <td colspan=2 style="text-align:center">True</td>
#     <td colspan=2 style="text-align:center">False</td>
#     <td colspan=2 style="text-align:center">False</td>
#   </tr>
#   <tr style="border-bottom: 1px solid black">
#     <td>112580</td>
#     <td style="text-align: center">Hims</td>
#     <td style="text-align: center">andrewdudum 🚀</td>
#     <td style="width:40%;text-align:left" colspan=6>Hims is a men's wellness brand built to help guys tackle those uncomfortable topics related to their health. Men aren't supposed to care for themselves. We call bullshit. We offer products to prevent hair loss, erectile disfunction, aging skin, and more of the stuff you care about.</td>
#     <td colspan=2 style="text-align:center">+2</td>
#     <td colspan=2 style="text-align:center">-3</td>
#     <td colspan=2 style="text-align:center">True</td>
#     <td colspan=2 style="text-align:center">True</td>
#     <td colspan=2 style="text-align:center">False</td>
#   </tr>
#   <tr style="border-bottom: 1px solid black">
#     <td>119579</td>
#     <td style="text-align: center">Deep Learning Platform (DLP)</td>
#     <td style="text-align: center">Nasser Njikam</td>
#     <td style="width:40%;text-align:left" colspan=6>Hello world!I am DLP for developers. You can "use" me to -among other things- Train and Deploy state of the art Caffe models for classifications without writing a single line of code. Image segmentation is also supported.I provide main modules of a DL application pipeline: Data, Net, Train, and Deploy.Can't wait to hear from you!</td>
#     <td colspan=2 style="text-align:center">+2</td>
#     <td colspan=2 style="text-align:center">-1</td>
#     <td colspan=2 style="text-align:center">True</td>
#     <td colspan=2 style="text-align:center">False</td>
#     <td colspan=2 style="text-align:center">False</td>
#   </tr>
# </table>

# %% [markdown]
# **Linguistic.** Si è operato sul fattore linguistic nel seguente modo: <br>
# è stato usato l'algoritmo **LDA (Latent Dirichlet Allocation)** fornito dalla libreria di python ```Scikit-Learn```, la più popolare libreria di machine learning (in questo progetto è stata usata la versione 0.21.2). <br>
# Per elaborare i testi sono state utilizzate le librerie per espressioni regolari ```regex```, ```gensim```, ```spacy```; per la visualizzazione grafica è stata utilizzata la libreria ```matplotlib```, infine per la manipolazione e la visualizzazione dei dati in forma tabellare sono state utilizzate le librerie ```numpy``` e ```pandas```.

# %%
import os
import numpy as np
import pandas as pd
import regex
import spacy
import gensim

# Sklearn
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import GridSearchCV
from pprint import pprint

# Plotting tools
import matplotlib.pyplot as plt

# %%
# Import dataset
csv_directory = os.getcwd()[:-8] + 'dataset\\'
csv_file_name = 'features_not_discretized.csv'
csv_path = os.path.join(csv_directory, csv_file_name)
df = pd.read_csv(csv_path, delimiter=';', usecols=['post_name', 'post_description', 'post_tagline'])
df.head(15)
# Out:
#                        post_name  \
# 0                      Hotjar v1
# 1                          F5Bot
# 2                           Hims
# 3   Deep Learning Platform (DLP)
# 4                          DLive
# 5                        Sunsama
# 6                     Brightland
# 7                          TOTLE
# 8                Tens Sunglasses
# 9             Problem of the day
# 10                       MakeHub
# 11                    UI Goodies
# 12                        Stumpy
# 13         Smart Slack Reminders
# 14                  ContactInBio
#
#                                      post_description  \
# 0   Hotjar v1 is a new and easy way to truly under...
# 1   F5Bot is a free service that emails you when y...
# 2   Hims is a men's wellness brand built to help g...
# 3   Hello world!\n\nI am DLP for developers. You c...
# 4   DLive is the first decentralized live streamin...
# 5   Sunsama organizes all the work you need to do ...
# ...

# %% [markdown]
# Per ogni post sono stati rimossi dalla *tagline* e dalla *description* email, caratteri di nuova linea (\n) e spazi extra.

# %%
# Remove email and new line characters
def remove_email_and_new_line_chars(text):
    _data = text.values.tolist()  # Convert to list
    _data = [regex.sub(r'\S*@\S*\s?', '', str(sent)) for sent in _data]  # Remove Emails
    _data = [regex.sub(r'\s+', ' ', str(sent)) for sent in _data]  # Remove new line characters
    _data = [regex.sub("\'", "", sent) for sent in _data]  # Remove distracting single quotes
    return _data

data = remove_email_and_new_line_chars(df.post_tagline)
pprint(data[:1])
print('\n')
data = remove_email_and_new_line_chars(df.post_description)
pprint(data[:1])
# Out:
# ['See how your visitors are really using your site – for free']
#
#
# ['Hotjar v1 is a new and easy way to truly understand your web and mobile site '
#  'visitors. Find your hottest opportunities for growth today.']

# %% [markdown]
# Inoltre, ogni frase è stata tokenizzata in una lista di parole eliminando totalmente punteggiatura e caratteri non necessari. Per fare questo è stata utilizzata la funzione ```simple_preprocess()``` fornita dalla libreria ```gensim```.

# %%
# Tokenize and Clean-up text
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))
print(data_words[:1])
# Out:
# [['hotjar', 'is', 'new', 'and', 'easy', 'way', 'to', 'truly', 'understand', 'your', 'web', 'and', 'mobile', 'site', 'visitors', 'find', 'your', 'hottest', 'opportunities', 'for', 'growth', 'today']]

# %% [markdown]
# Successivamente è stata effettuata la lemmatizzazione, cioè un processo che riporta le parole alla propria radice. Questo processo serve a ridurre il numero totale delle parole univoche presenti nel dizionario e come risultato il numero di colonne nella matrice documento-parola sarà più denso con meno colonne.

# %%
# Lemmatization
def lemmatization(texts, allowed_postags, nlp):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent))
        texts_out.append(" ".join([token.lemma_ if token.lemma_ not in ['-PRON-'] else '' for token in doc if token.pos_ in allowed_postags]))
    return texts_out

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])  

# Do lemmatization keeping only Noun, Adj, Verb, Adverb
data_lemmatized = lemmatization(data_words, ['NOUN', 'ADJ', 'VERB', 'ADV'], nlp)  
                                                                                      
print(data_lemmatized[:2])
# Out:
# ['hotjar be new easy way truly understand web mobile site visitor find hot opportunity growth today', 'bot be free service email when select keyword be mention reddit hacker news lobster use monitor brand project just topic be interested']

# %% [markdown]
# A questo punto è stata creata la matrice documento-parola utilizzando la classe ```CountVectorizer```, in quanto l'algoritmo LDA per topic modeling richiede una matrice documento-parola come input principale. Innanzitutto è stata inizializzata la classe CountVectorizer per considerare le parole che sono presenti almeno 10 volte, per rimuovere le stop-word e per convertire in minuscolo tutte le parole. Successivamente è stata applicata la funzione ```fit_transform()``` per creare la matrice. <br>
# Poichè la maggior parte delle celle contiene il valore 0, il risultato sarà sottoforma di una matrice sparsa per risparmiare memoria.

# %%
# Create the Document-Word matrix
vectorizer = CountVectorizer(analyzer='word',
                             min_df=10,                        # minimum required occurences of a word
                             stop_words='english',             # remove english stop words
                             lowercase=True,                   # convert all words to lowercase
                             token_pattern='[a-zA-Z0-9]{3,}',  # number of chars in a word > 3
                             )
data_vectorized = vectorizer.fit_transform(data_lemmatized)

# %% [markdown]
# La sparsità non è altro che la percentuale di punti dati diversi da 0 nella matrice documento-parola (```data_vectorized```) e per sapere qual è questa percentuale viene eseguito il seguente codice:

# %%
# Check the Sparsicity
data_dense = data_vectorized.todense()  # Materialize the sparse data
print("Sparsicity: ", ((data_dense > 0).sum() / data_dense.size) * 100, "%")  # Compute Sparsicity = Percentage of Non-Zero cells
# Out:
# Sparsicity:  1.0925546992105015 %

# %% [markdown]
# A questo punto è stato inizializzato un modello LDA settando il numero di topic a 10. Inoltre, è stata richiamata la funzione ```fit_transform()``` per costruire il modello LDA.

# %%
# Build LDA model with sklearn
lda_model = LatentDirichletAllocation(n_components=10,            # Number of topics
                                      max_iter=10,                # Max learning iterations
                                      learning_method='online',
                                      random_state=100,           # Random state
                                      batch_size=128,             # number of documents in each learning iter
                                      evaluate_every=-1,          # compute perplexity every n iters, default: Don't
                                      n_jobs=-1,                  # Use all available CPUs
                                      )
lda_output = lda_model.fit_transform(data_vectorized)
print(lda_model)  # Model attributes
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='online', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=10, n_jobs=-1,
#                           perp_tol=0.1, random_state=100, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %% [markdown]
# Successivamente sono state controllate le prestazioni del modello LDA sulla base di perplessità e verosimiglianza. Un modello con una più alta verosimiglianza e una minore perplessità è considerato buono.

# %%
# Diagnose model performance with perplexity and log-likelihood
print("Log Likelihood: ", lda_model.score(data_vectorized))  # Log Likelyhood: Higher the better
print("Perplexity: ", lda_model.perplexity(data_vectorized))   # Perplexity: Lower the better. Perplexity = exp(-1. * log-likelihood per word)
pprint(lda_model.get_params())  # See model parameters
# Out:
# Log Likelihood:  -378857.6083385622
# Perplexity:  975.3670878416933
# {'batch_size': 128,
#  'doc_topic_prior': None,
#  'evaluate_every': -1,
#  'learning_decay': 0.7,
#  'learning_method': 'online',
#  'learning_offset': 10.0,
#  'max_doc_update_iter': 100,
#  'max_iter': 10,
#  'mean_change_tol': 0.001,
#  'n_components': 10,
#  'n_jobs': -1,
#  'perp_tol': 0.1,
#  'random_state': 100,
#  'topic_word_prior': None,
#  'total_samples': 1000000.0,
#  'verbose': 0}

# %% [markdown]
# In seguito è stato cercato il miglior modello LDA prendendo in considerazione due importanti parametri di ottimizzazione per i modelli LDA: ```n_components``` (numero di topic) e ```learning_decay``` (controlla il tasso di apprendimento).

# %%
# GridSearch the best LDA model
search_params = {'n_components': [3], 'learning_decay': [.5, .7, .9]}  # Define Search Param
model = GridSearchCV(lda_model, param_grid=search_params, n_jobs=1, iid=True, cv=3, error_score='raise')  # Init Grid Search Class
model.fit(data_vectorized)  # Do the Grid Search
# Out:
# GridSearchCV(cv=3, error_score='raise',
#              estimator=LatentDirichletAllocation(batch_size=128,
#                                                  doc_topic_prior=None,
#                                                  evaluate_every=-1,
#                                                  learning_decay=0.7,
#                                                  learning_method='online',
#                                                  learning_offset=10.0,
#                                                  max_doc_update_iter=100,
#                                                  max_iter=10,
#                                                  mean_change_tol=0.001,
#                                                  n_components=10, n_jobs=-1,
#                                                  perp_tol=0.1, random_state=100,
#                                                  topic_word_prior=None,
#                                                  total_samples=1000000.0,
# ...

# %%
# Find the best topic model and its parameters
best_lda_model = model.best_estimator_  # Best Model
print("Best Model's Params: ", model.best_params_)  # Model Parameters
print("Best Log Likelihood Score: ", model.best_score_)  # Log Likelihood Score
print("Model Perplexity: ", best_lda_model.perplexity(data_vectorized))  # Perplexity
# Out:
# Best Model's Params:  {'learning_decay': 0.5, 'n_components': 3}
# Best Log Likelihood Score:  -128522.70908189783
# Model Perplexity:  821.6917852045635

# %% [markdown]
# Inoltre, è stato visualizzato il topic dominante in ciascun documento. Per stabilire qual è il topic dominante in un documento bisogna vedere quale topic ha il maggior contributo a quel documento e assegnarlo. <br>
# Nella tabella seguente, si sono segnati in verde tutti i topic principali in un documento ed evidenziato in giallo il topic più dominante.

# %%
# Create Document - Topic Matrix to see the dominant topic in each document
def create_document_topic_matrix(blm, doc_word_matrix, data):
    lda_output = blm.transform(doc_word_matrix)  
    topicnames = ["Topic" + str(i) for i in range(blm.n_components)]  # column names
    docnames = ["Doc" + str(i) for i in range(len(data))]  # index names
    df_doc_topic = pd.DataFrame(np.round(lda_output, 2), columns=topicnames, index=docnames)  # Make the pandas dataframe
    return df_doc_topic

# Styling
def color_green(val):
    color = 'green' if val > .1 else 'black'
    return 'color: {col}'.format(col=color)

def make_bold(val):
    weight = 700 if val > .1 else 400
    return 'font-weight: {weight}'.format(weight=weight)

# Apply Style
df_document_topic = create_document_topic_matrix(best_lda_model, data_vectorized, data)
n_documents = 15
df_document_topics = df_document_topic.head(n_documents).style.applymap(color_green).applymap(make_bold).highlight_max(color='yellow', axis=1)
df_document_topics
# Out:
# <style  type="text/css" >
#     #T_ca9c6c7e_ff45_11e9_99f7_c8d3ff2b1725row0_col0 {
#             color:  green;
#             font-weight:  700;
#             background-color:  yellow;
#         }    #T_ca9c6c7e_ff45_11e9_99f7_c8d3ff2b1725row0_col1 {
#             color:  black;
#             font-weight:  400;
#             : ;
#         }    #T_ca9c6c7e_ff45_11e9_99f7_c8d3ff2b1725row0_col2 {
#             color:  green;
#             font-weight:  700;
#             : ;
#         }    #T_ca9c6c7e_ff45_11e9_99f7_c8d3ff2b1725row1_col0 {
#             color:  green;
#             font-weight:  700;
#             background-color:  yellow;
#         }    #T_ca9c6c7e_ff45_11e9_99f7_c8d3ff2b1725row1_col1 {
#             color:  green;
#             font-weight:  700;
#             : ;
#         }    #T_ca9c6c7e_ff45_11e9_99f7_c8d3ff2b1725row1_col2 {
#             color:  green;
#             font-weight:  700;
#             : ;
# ...

# %% [markdown]
# Infine per ogni topic sono state prese le prime 15 keyword con il punteggio più alto utilizzando la funzione ```show_topics()```.

# %%
def show_topics(vectorizer, best_lda_model, n_words):
    keywords = np.array(vectorizer.get_feature_names())
    topic_keywords = []
    for topic_weights in best_lda_model.components_:
        found = 0
        key_words = []
        top_keyword_locs = (-topic_weights).argsort()[:n_words]
        for i in range(0, len(keywords.take(top_keyword_locs))):
            if keywords.take(top_keyword_locs)[i] == 'nan':
                found = 1
                top_keyword_locs = (-topic_weights).argsort()[:n_words+1]
                key_words.append(keywords.take(top_keyword_locs)[i+1])
            else:
                if found == 0:
                    key_words.append(keywords.take(top_keyword_locs)[i])
                else:
                    key_words.append(keywords.take(top_keyword_locs)[i+1])
        topic_keywords.append(key_words)
    return topic_keywords

topic_keywords = show_topics(vectorizer, best_lda_model, 15)  # Show top n keywords for each topic. In this case n is equal to 15
df_topic_keywords = pd.DataFrame(topic_keywords)  # Topic- Keywords Dataframe
df_topic_keywords.columns = ['Word ' + str(i) for i in range(df_topic_keywords.shape[1])]
df_topic_keywords.index = ['Topic ' + str(i) for i in range(df_topic_keywords.shape[0])]
df_topic_keywords
# Out:
#         Word 0  Word 1 Word 2   Word 3 Word 4  Word 5 Word 6   Word 7  Word 8  \
# Topic 0    use    tool  build      app   user  design    web  project   datum
# Topic 1    app    game  video      use   make  create    new   design  friend
# Topic 2   help  people  email  product   time    make   good      day     new
#
#            Word 9  Word 10 Word 11 Word 12 Word 13 Word 14
# Topic 0  platform  website    help    code  create    free
# Topic 1      time    photo   image   world    just    play
# Topic 2       way   social    link   share   place    list

# %%
# Add column Topic to the features csv file
dominant_topic = np.argmax(df_document_topic.values, axis=1)
features = pd.read_csv(csv_path, delimiter=';')
features['topic'] = dominant_topic
features.to_csv(csv_path, sep=';', index=False)

# %%
f = pd.read_csv(csv_path, delimiter=';')
pd.set_option('display.max_columns', 52)
f.head()
# Out:
#    post_id                     post_name  version  tags_number is_featured  \
# 0    29143                     Hotjar v1      1.0            4         Yes
# 1    91504                         F5Bot      1.0            6         Yes
# 2   112580                          Hims      1.0            2         Yes
# 3   119579  Deep Learning Platform (DLP)      1.0            3         Yes
# 4   121620                         DLive      1.0            4         Yes
#
#    score created_at_day   created_at_daytime launched_day  \
# 0   2771     30/08/2018  28/07/2015 05:12:28      Tuesday
# 1    313     12/10/2018  12/10/2018 00:00:00       Friday
# 2    442     10/09/2018  03/11/2017 03:02:00       Friday
# 3    208     08/12/2018  08/12/2018 00:00:00     Saturday
# 4    166     06/07/2018  06/07/2018 00:00:00       Friday
#
#   is_best_time_to_launch is_best_day_to_launch is_weekend  \
# 0                    Yes                   Yes         No
# ...

# %% [markdown]
# ### *3. Dataset*
# Il Dataset impiegato in questo studio è stato ottenuto da un dump di tutte le informazioni relative ai post lanciati dal 16 Dicembre 2013 al 10 Giugno 2019. Nello specifico questo dataset contiene 7021 post totali. Tuttavia è stato possibile analizzarne solo 3537, in quanto i restanti 3484 post sono stati scartati perchè presentavano maker_id nulli o mutlipli: nel dettaglio 2396 post presentavano maker id nulli, 1043 post presentavano maker id multipli, infine 45 post erano stati completamente rimossi dal sito di PH.
